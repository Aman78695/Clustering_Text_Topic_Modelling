# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman78695/Clustering_Text_Topic_Modelling/blob/main/Clustering_Text_Topic_Modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.cluster import KMeans
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import string
# Download NLTK resources (only required once)
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Convert data to DataFrame
data = pd.read_csv('/content/Radar Sample Data - Sheet1.csv')

# %%
data.head()
# Out:
#                   name                                        profileLink  \
# 0       Archita Pandey  https://www.linkedin.com/in/architapandey29?mi...
# 1  Usama Arshad Jadoon  https://www.linkedin.com/in/muhammad-asad-mune...
# 2               satbee                                https://kasfdj.scom
# 3               satbee                                https://kasfdj.scom
# 4       Nicholas Ocket  https://www.linkedin.com/in/nicholas-ocket?min...
#
#                                              message                  date  \
# 0  🚀 Excited to Share My Portfolio and Journey! 📚...  2023-07-24, 07:40:54
# 1  Tag your software tester who loves finding bug...  2023-07-24, 07:40:54
# 2                                          sdfsdfsdf  2023-07-25, 07:25:26
# 3                                          sdfsdfsdf  2023-07-25, 07:25:27
# 4  Hey junior developers. Do you understand why d...  2023-07-28, 09:14:02
#
#   likes            searchTag  \
# 0    13                  NaN
# ...

# %%
import re

# %%
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()

    # Remove emojis and symbols
    text = re.sub(r'[^\w\s]', '', text)
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Tokenization
    tokens = word_tokenize(text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    # Stemming
    # stemmer = PorterStemmer()
    # tokens = [stemmer.stem(word) for word in tokens]
    # Join tokens back to string
    processed_text = ' '.join(tokens)
    return processed_text

# Example usage

data['processed_message'] = data['message'].apply(preprocess_text)

# %%
data.head()
# Out:
#                   name                                        profileLink  \
# 0       Archita Pandey  https://www.linkedin.com/in/architapandey29?mi...
# 1  Usama Arshad Jadoon  https://www.linkedin.com/in/muhammad-asad-mune...
# 2               satbee                                https://kasfdj.scom
# 3               satbee                                https://kasfdj.scom
# 4       Nicholas Ocket  https://www.linkedin.com/in/nicholas-ocket?min...
#
#                                              message                  date  \
# 0  🚀 Excited to Share My Portfolio and Journey! 📚...  2023-07-24, 07:40:54
# 1  Tag your software tester who loves finding bug...  2023-07-24, 07:40:54
# 2                                          sdfsdfsdf  2023-07-25, 07:25:26
# 3                                          sdfsdfsdf  2023-07-25, 07:25:27
# 4  Hey junior developers. Do you understand why d...  2023-07-28, 09:14:02
#
#   likes            searchTag  \
# 0    13                  NaN
# ...

# %%
# Convert messages to bag-of-words features
vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(data['processed_message'])

# %%
# Apply LDA
num_topics = 4  # Number of topics
lda = LatentDirichletAllocation(n_components=num_topics, random_state=42)
lda.fit(X)
# Out:
# LatentDirichletAllocation(n_components=4, random_state=42)

# %%
# Get topic distribution for each message
topic_dist = lda.transform(X)

# %%
lda.exp_dirichlet_component_
# Out:
# array([[9.19295691e-07, 1.09637658e-04, 9.19281266e-07, ...,
#         9.19280083e-07, 9.19367256e-07, 5.01876709e-05],
#        [5.30427606e-07, 8.79690145e-07, 5.30427218e-07, ...,
#         1.00517389e-04, 5.30457414e-07, 5.30434246e-07],
#        [5.19903783e-07, 5.19958973e-07, 2.83844463e-05, ...,
#         5.19902217e-07, 2.05152717e-04, 5.19908239e-07],
#        [4.21782067e-05, 7.72692416e-07, 7.72567136e-07, ...,
#         7.72565290e-07, 7.72628754e-07, 7.72577091e-07]])

# %%
# Assign topics to DataFrame based on highest topic probability
data['topic'] = topic_dist.argmax(axis=1)

# %%
# Define topic labels
topic_labels = {
    0: 'Software Development Best Practices and Advice.',
    1: 'Self-promotion and Networking in the Software Development Industry',
    2: 'Career Goals'
}

# Map topic indices to labels
data['topic_label'] = data['topic'].map(topic_labels)

# %%
# Print DataFrame with topics
data.head(10)
# Out:
#                                        name  \
# 0                            Archita Pandey
# 1                       Usama Arshad Jadoon
# 2                                    satbee
# 3                                    satbee
# 4                            Nicholas Ocket
# 5                               Rishi Kumar
# 6                         Kateryna Kuzmenko
# 7                      Ovidiu Petru Muntean
# 8  شاغر دوت كوم - وظائف الامارات - UAE JOBS
# 9                        MANKIND PHARMA LTD
#
#                                          profileLink  \
# 0  https://www.linkedin.com/in/architapandey29?mi...
# 1  https://www.linkedin.com/in/muhammad-asad-mune...
# 2                                https://kasfdj.scom
# 3                                https://kasfdj.scom
# 4  https://www.linkedin.com/in/nicholas-ocket?min...
# 5  https://www.linkedin.com/in/rishi02525?miniPro...
# 6  https://www.linkedin.com/in/kateryna-kuzmenko-...
# ...
